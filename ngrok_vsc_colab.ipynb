# %%
# Install useful stuff
! apt install --yes ssh screen nano htop ranger git > /dev/null
# SSH setting
! echo "root:123456" | chpasswd
! echo "PasswordAuthentication yes" > /etc/ssh/sshd_config
! echo "PermitUserEnvironment yes" >> /etc/ssh/sshd_config
! echo "PermitRootLogin yes" >> /etc/ssh/sshd_config
! service ssh restart > /dev/null
# Download ngrok
! wget -q -c -nc https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
! unzip -qq -n ngrok-stable-linux-amd64.zip
# Run ngrok
authtoken = "YOUR NGROK TOKEN HERE!!!!!!!!!!!!!!!!!!!!"
get_ipython().system_raw('./ngrok authtoken $authtoken && ./ngrok tcp 22 &')
! sleep 3
# Get the address for SSH
import requests
from re import sub
r = requests.get('http://localhost:4040/api/tunnels')
str_ssh = r.json()['tunnels'][0]['public_url']
str_ssh = sub("tcp://", "", str_ssh)
str_ssh = sub(":", " -p ", str_ssh)
str_ssh_for_vsc = "ssh -L 9999:localhost:9999 root@" + str_ssh
str_ssh = "ssh root@" + str_ssh
print(str_ssh)
# Out:
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
# ssh root@0.tcp.ngrok.io -p 17108

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Mount Google Drive and make some folders for vscode
from google.colab import drive
drive.mount('/googledrive')
! mkdir -p /googledrive/My\ Drive/colabdrive
! mkdir -p /googledrive/My\ Drive/colabdrive/root/.local/share/code-server
! ln -s /googledrive/My\ Drive/colabdrive /
! ln -s /googledrive/My\ Drive/colabdrive/root/.local/share/code-server /root/.local/share/
# Out:
# Mounted at /googledrive

# %%
print("copy following cmd to your local machine and run it in terminal:")
print(str_ssh_for_vsc)
! curl -fsSL https://code-server.dev/install.sh | sh > /dev/null
! code-server --bind-addr 127.0.0.1:9999 --auth none &
# Out:
# copy following cmd to your local machine and run it in terminal:
# ssh -L 9999:localhost:9999 root@0.tcp.ngrok.io -p 17108
# ######################################################################## 100.0%
# [2022-05-04T16:53:20.507Z] info  Wrote default config file to ~/.config/code-server/config.yaml
# [2022-05-04T16:53:21.037Z] info  code-server 4.3.0 09bc30027a7fbba170f907a527eaa9f7219fe739
# [2022-05-04T16:53:21.038Z] info  Using user-data-dir ~/.local/share/code-server
# [2022-05-04T16:53:21.077Z] info  Using config file ~/.config/code-server/config.yaml
# [2022-05-04T16:53:21.078Z] info  HTTP server listening on http://127.0.0.1:9999/
# [2022-05-04T16:53:21.079Z] info    - Authentication is disabled
# [2022-05-04T16:53:21.080Z] info    - Not serving HTTPS
# [16:54:45] Extension host agent started.
# [16:54:47] [File Watcher (node.js)] correcting a path to watch that seems to be a symbolic link or wrong casing (original: /root/.local/share/code-server/Machine, real: /googledrive/My Drive/colabdrive/root/.local/share/code-server/Machine)
# [16:54:47] [File Watcher (node.js)] correcting a path to watch that seems to be a symbolic link or wrong casing (original: /root/.local/share/code-server/extensions, real: /googledrive/My Drive/colabdrive/root/.local/share/code-server/extensions)
# [16:54:53] [127.0.0.1][2f4d7f84][ManagementConnection] New connection established.
# [16:54:54] [File Watcher (node.js)] correcting a path to watch that seems to be a symbolic link or wrong casing (original: /root/.local/share/code-server/User, real: /googledrive/My Drive/colabdrive/root/.local/share/code-server/User)
# [16:54:54] [File Watcher (node.js)] correcting a path to watch that seems to be a symbolic link or wrong casing (original: /root/.local/share/code-server/User/settings.json, real: /googledrive/My Drive/colabdrive/root/.local/share/code-server/User/settings.json)
# [16:54:55] [File Watcher (node.js)] correcting a path to watch that seems to be a symbolic link or wrong casing (original: /root/.local/share/code-server/Machine, real: /googledrive/My Drive/colabdrive/root/.local/share/code-server/Machine)
# [16:54:59] [127.0.0.1][1380f8c4][ExtensionHostConnection] New connection established.
# [16:54:59] [127.0.0.1][1380f8c4][ExtensionHostConnection] <1489> Launched Extension Host Process.
# [16:55:02] [File Watcher (node.js)] correcting a path to watch that seems to be a symbolic link or wrong casing (original: /root/.local/share/code-server/User/snippets, real: /googledrive/My Drive/colabdrive/root/.local/share/code-server/User/snippets)

# %%
#! curl -fsSL https://code-server.dev/install.sh | sh > /dev/null
#! code-server --bind-addr 127.0.0.1:7860 --auth none &
